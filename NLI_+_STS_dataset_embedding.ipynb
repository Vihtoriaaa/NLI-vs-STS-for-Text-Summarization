# %% [markdown]
# ### Imports

# %%
import pandas as pd
import pickle
import numpy as np
import warnings
warnings.filterwarnings('ignore')

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install contractions
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: contractions in /usr/local/lib/python3.10/dist-packages (0.1.73)
# Requirement already satisfied: textsearch>=0.0.21 in /usr/local/lib/python3.10/dist-packages (from contractions) (0.0.24)
# Requirement already satisfied: anyascii in /usr/local/lib/python3.10/dist-packages (from textsearch>=0.0.21->contractions) (0.3.2)
# Requirement already satisfied: pyahocorasick in /usr/local/lib/python3.10/dist-packages (from textsearch>=0.0.21->contractions) (2.0.0)

# %%
# !pip install sentence_transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: sentence_transformers in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (4.29.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (4.65.0)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (2.0.1+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (0.15.2+cu118)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.22.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.10.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (3.8.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (0.1.99)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (0.14.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (3.12.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (2023.4.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (2.27.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (23.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence_transformers) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence_transformers) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence_transformers) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence_transformers) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence_transformers) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence_transformers) (16.0.5)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (2022.10.31)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (0.13.3)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence_transformers) (8.1.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->sentence_transformers) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence_transformers) (3.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence_transformers) (8.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->sentence_transformers) (2.1.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (3.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->sentence_transformers) (1.3.0)

# %%
from sentence_transformers import SentenceTransformer, util
model = SentenceTransformer('all-MiniLM-L6-v2')

# %% [markdown]
# ### Data Loading

# %%
df_train = pd.read_csv("/content/drive/MyDrive/ml-project-data-try/snli-preprocessed/snli_data_train.csv")
# df_train.dropna(inplace=True)
# df_train.reset_index(drop=True)
print(f"number of rows: {df_train.shape[0]}")
print(f"number of columns: {df_train.shape[1]}")
df_train.head()
# Out:
# number of rows: 549367
# number of columns: 3
#            label                             premise  \
# 0        neutral  person horse jumps broken airplane
# 1  contradiction  person horse jumps broken airplane
# 2     entailment  person horse jumps broken airplane
# 3        neutral      children smiling waving camera
# 4     entailment      children smiling waving camera
#
#                           hypothesis
# 0  person training horse competition
# 1     person diner ordering omelette
# 2              person outdoors horse
# 3                    smiling parents
# 4                   children present

# %%
df_train = df_train.dropna().reset_index(drop=True)
print(f"number of rows: {df_train.shape[0]}")
print(f"number of columns: {df_train.shape[1]}")
df_train.tail()
# Out:
# number of rows: 549350
# number of columns: 3
#                 label                                    premise  \
# 549345  contradiction             four dirty barefooted children
# 549346        neutral             four dirty barefooted children
# 549347        neutral  man surfing bodysuit beautiful blue water
# 549348  contradiction  man surfing bodysuit beautiful blue water
# 549349     entailment  man surfing bodysuit beautiful blue water
#
#                                             hypothesis
# 549345                  four kids awards cleanest feet
# 549346  four homeless children shoes stolen feet dirty
# 549347      man bodysuit competing surfing competition
# 549348         man business suit heading board meeting
# 549349       beautiful blue water man bodysuit surfing

# %%
df_val = pd.read_csv("/content/drive/MyDrive/ml-project-data-try/snli-preprocessed/snli_data_val.csv")
df_val.dropna(inplace=True)
print(f"number of rows: {df_val.shape[0]}")
print(f"number of columns: {df_val.shape[1]}")
df_val.head()
# Out:
# number of rows: 9842
# number of columns: 3
#            label                                            premise  \
# 0        neutral            two women embracing holding go packages
# 1     entailment            two women embracing holding go packages
# 2  contradiction            two women embracing holding go packages
# 3     entailment  two young children blue jerseys one number nin...
# 4        neutral  two young children blue jerseys one number nin...
#
#                                           hypothesis
# 0  sisters hugging goodbye holding go packages ea...
# 1                         two woman holding packages
# 2                          men fighting outside deli
# 3               two kids numbered jerseys wash hands
# 4                       two kids ballgame wash hands

# %%
df_test = pd.read_csv("/content/drive/MyDrive/ml-project-data-try/snli-preprocessed/snli_data_test.csv")
df_test.dropna(inplace=True)
print(f"number of rows: {df_test.shape[0]}")
print(f"number of columns: {df_test.shape[1]}")
df_test.head()
# Out:
# number of rows: 9824
# number of columns: 3
#            label                                            premise  \
# 0        neutral  church choir sings masses sing joyous songs bo...
# 1     entailment  church choir sings masses sing joyous songs bo...
# 2  contradiction  church choir sings masses sing joyous songs bo...
# 3        neutral          woman green headscarf blue shirt big grin
# 4     entailment          woman green headscarf blue shirt big grin
#
#                     hypothesis
# 0        church cracks ceiling
# 1           church filled song
# 2  choir singing baseball game
# 3                  woman young
# 4                  woman happy

# %% [markdown]
# ### Word embedding

# %% [markdown]
# #### Train data

# %%
hypothesis_train = np.array(df_train['hypothesis'])
premise_train = np.array(df_train['premise'])

# %%
embeddings_hypothesis_train = model.encode(hypothesis_train, show_progress_bar=True, convert_to_tensor=True)
embeddings_premise_train = model.encode(premise_train, convert_to_tensor=True)
# Out:
# Batches:   0%|          | 0/17168 [00:00<?, ?it/s]

# %%
df_train['cosine_scores'] = df_train.apply(lambda row: util.cos_sim(embeddings_hypothesis_train[row.name].cpu().numpy(), embeddings_premise_train[row.name].cpu().numpy()), axis=1)
df_train.head()
# Out:
#            label                             premise  \
# 0        neutral  person horse jumps broken airplane
# 1  contradiction  person horse jumps broken airplane
# 2     entailment  person horse jumps broken airplane
# 3        neutral      children smiling waving camera
# 4     entailment      children smiling waving camera
#
#                           hypothesis       cosine_scores
# 0  person training horse competition  [[tensor(0.3876)]]
# 1     person diner ordering omelette  [[tensor(0.0481)]]
# 2              person outdoors horse  [[tensor(0.5148)]]
# 3                    smiling parents  [[tensor(0.5946)]]
# 4                   children present  [[tensor(0.5699)]]

# %%
df_train['cosine_scores'] = df_train['cosine_scores'].apply(lambda x: x.item())
df_train.head()
# Out:
#            label                             premise  \
# 0        neutral  person horse jumps broken airplane
# 1  contradiction  person horse jumps broken airplane
# 2     entailment  person horse jumps broken airplane
# 3        neutral      children smiling waving camera
# 4     entailment      children smiling waving camera
#
#                           hypothesis  cosine_scores
# 0  person training horse competition       0.387597
# 1     person diner ordering omelette       0.048144
# 2              person outdoors horse       0.514768
# 3                    smiling parents       0.594589
# 4                   children present       0.569901

# %%
def preprocess_data(df, embedded_hypothesis, embedded_premise):
    processed_data = []
    
    for index, row in df.iterrows():
        # Get label, premise, and hypothesis from the row
        label = row['label']
        premise = row['premise']
        hypothesis = row['hypothesis']

        hypothesis_embedded = embedded_hypothesis[index].cpu().numpy()
        premise_embedded = embedded_premise[index].cpu().numpy()
        cosine_score = row['cosine_scores']
        
        # Append the processed data as a tuple to the list
        processed_data.append((premise, hypothesis, label, premise_embedded, hypothesis_embedded, cosine_score))
    
    return pd.DataFrame(processed_data, columns=['premise', 'hypothesis', 'label', 'premise_embedded', 'hypothesis_embedded', 'cosine_score'])

# %%
df_train_final = df_train.copy()
processed_train_data = preprocess_data(df_train_final, embeddings_hypothesis_train, embeddings_premise_train) 
processed_train_data.head()
# Out:
#                               premise                         hypothesis  \
# 0  person horse jumps broken airplane  person training horse competition
# 1  person horse jumps broken airplane     person diner ordering omelette
# 2  person horse jumps broken airplane              person outdoors horse
# 3      children smiling waving camera                    smiling parents
# 4      children smiling waving camera                   children present
#
#            label                                   premise_embedded  \
# 0        neutral  [-0.010034064, 0.0028005873, 0.0631274, 0.0080...
# 1  contradiction  [-0.010034064, 0.0028005873, 0.0631274, 0.0080...
# 2     entailment  [-0.010034064, 0.0028005873, 0.0631274, 0.0080...
# 3        neutral  [-0.021928668, 0.06378024, 0.017834725, -0.032...
# 4     entailment  [-0.021928668, 0.06378024, 0.017834725, -0.032...
#
#                                  hypothesis_embedded  cosine_score
# 0  [-0.050083168, 0.020744428, 0.006436512, -0.00...      0.387597
# 1  [0.01991658, 0.08336658, 0.05666334, -0.005686...      0.048144
# 2  [-0.015296373, 0.051944993, 0.06472147, -0.013...      0.514768
# 3  [-0.038321618, 0.09435368, 0.0064652245, 0.039...      0.594589
# 4  [-0.018334052, 0.032883544, -0.014544778, 0.03...      0.569901

# %% [markdown]
# #### Validation data

# %%
hypothesis_val = np.array(df_val['hypothesis'])
premise_val = np.array(df_val['premise'])

# %%
embeddings_hypothesis_val = model.encode(hypothesis_val, show_progress_bar=True, convert_to_tensor=True)
embeddings_premise_val = model.encode(premise_val, convert_to_tensor=True)
# Out:
# Batches:   0%|          | 0/308 [00:00<?, ?it/s]

# %%
df_val['cosine_scores'] = df_val.apply(lambda row: util.cos_sim(embeddings_hypothesis_val[row.name].cpu().numpy(), embeddings_premise_val[row.name].cpu().numpy()), axis=1)
df_val.head()
# Out:
#            label                                            premise  \
# 0        neutral            two women embracing holding go packages
# 1     entailment            two women embracing holding go packages
# 2  contradiction            two women embracing holding go packages
# 3     entailment  two young children blue jerseys one number nin...
# 4        neutral  two young children blue jerseys one number nin...
#
#                                           hypothesis       cosine_scores
# 0  sisters hugging goodbye holding go packages ea...  [[tensor(0.5833)]]
# 1                         two woman holding packages  [[tensor(0.7639)]]
# 2                          men fighting outside deli  [[tensor(0.0696)]]
# 3               two kids numbered jerseys wash hands  [[tensor(0.7535)]]
# 4                       two kids ballgame wash hands  [[tensor(0.5951)]]

# %%
df_val['cosine_scores'] = df_val['cosine_scores'].apply(lambda x: x.item())
df_val.head()
# Out:
#            label                                            premise  \
# 0        neutral            two women embracing holding go packages
# 1     entailment            two women embracing holding go packages
# 2  contradiction            two women embracing holding go packages
# 3     entailment  two young children blue jerseys one number nin...
# 4        neutral  two young children blue jerseys one number nin...
#
#                                           hypothesis  cosine_scores
# 0  sisters hugging goodbye holding go packages ea...       0.583258
# 1                         two woman holding packages       0.763924
# 2                          men fighting outside deli       0.069606
# 3               two kids numbered jerseys wash hands       0.753461
# 4                       two kids ballgame wash hands       0.595102

# %%
df_val_final = df_val.copy()
processed_val_data = preprocess_data(df_val_final, embeddings_hypothesis_val, embeddings_premise_val) 
processed_val_data.head()
# Out:
#                                              premise  \
# 0            two women embracing holding go packages
# 1            two women embracing holding go packages
# 2            two women embracing holding go packages
# 3  two young children blue jerseys one number nin...
# 4  two young children blue jerseys one number nin...
#
#                                           hypothesis          label  \
# 0  sisters hugging goodbye holding go packages ea...        neutral
# 1                         two woman holding packages     entailment
# 2                          men fighting outside deli  contradiction
# 3               two kids numbered jerseys wash hands     entailment
# 4                       two kids ballgame wash hands        neutral
#
#                                     premise_embedded  \
# 0  [0.0042251493, -0.003406235, -0.0019028404, 0....
# 1  [0.0042251493, -0.003406235, -0.0019028404, 0....
# 2  [0.0042251493, -0.003406235, -0.0019028404, 0....
# 3  [-0.08395465, 0.033306517, 0.05497519, -0.0349...
# 4  [-0.08395465, 0.033306517, 0.05497519, -0.0349...
#
#                                  hypothesis_embedded  cosine_score
# 0  [0.024690624, 0.09049612, 0.030129503, -0.0052...      0.583258
# 1  [-0.07236776, -0.020317988, -0.034565713, 0.02...      0.763924
# 2  [0.035375293, 0.042607836, -0.0109004835, 0.00...      0.069606
# 3  [-0.085580505, 0.06142286, 0.04118396, -0.0191...      0.753461
# 4  [-0.035818074, 0.0477772, 0.06401619, -0.03154...      0.595102

# %% [markdown]
# #### Test data

# %%
hypothesis_test = np.array(df_test['hypothesis'])
premise_test = np.array(df_test['premise'])

# %%
embeddings_hypothesis_test = model.encode(hypothesis_test, show_progress_bar=True, convert_to_tensor=True)
embeddings_premise_test = model.encode(premise_test, convert_to_tensor=True)
# Out:
# Batches:   0%|          | 0/307 [00:00<?, ?it/s]

# %%
df_test['cosine_scores'] = df_test.apply(lambda row: util.cos_sim(embeddings_hypothesis_test[row.name].cpu().numpy(), embeddings_premise_test[row.name].cpu().numpy()), axis=1)
df_test.head()
# Out:
#            label                                            premise  \
# 0        neutral  church choir sings masses sing joyous songs bo...
# 1     entailment  church choir sings masses sing joyous songs bo...
# 2  contradiction  church choir sings masses sing joyous songs bo...
# 3        neutral          woman green headscarf blue shirt big grin
# 4     entailment          woman green headscarf blue shirt big grin
#
#                     hypothesis       cosine_scores
# 0        church cracks ceiling  [[tensor(0.3420)]]
# 1           church filled song  [[tensor(0.6649)]]
# 2  choir singing baseball game  [[tensor(0.5633)]]
# 3                  woman young  [[tensor(0.3099)]]
# 4                  woman happy  [[tensor(0.5116)]]

# %%
df_test['cosine_scores'] = df_test['cosine_scores'].apply(lambda x: x.item())
df_test.head()
# Out:
#            label                                            premise  \
# 0        neutral  church choir sings masses sing joyous songs bo...
# 1     entailment  church choir sings masses sing joyous songs bo...
# 2  contradiction  church choir sings masses sing joyous songs bo...
# 3        neutral          woman green headscarf blue shirt big grin
# 4     entailment          woman green headscarf blue shirt big grin
#
#                     hypothesis  cosine_scores
# 0        church cracks ceiling       0.342046
# 1           church filled song       0.664867
# 2  choir singing baseball game       0.563270
# 3                  woman young       0.309873
# 4                  woman happy       0.511601

# %%
df_test_final = df_test.copy()
processed_test_data = preprocess_data(df_test_final, embeddings_hypothesis_test, embeddings_premise_test) 
processed_test_data.head()
# Out:
#                                              premise  \
# 0  church choir sings masses sing joyous songs bo...
# 1  church choir sings masses sing joyous songs bo...
# 2  church choir sings masses sing joyous songs bo...
# 3          woman green headscarf blue shirt big grin
# 4          woman green headscarf blue shirt big grin
#
#                     hypothesis          label  \
# 0        church cracks ceiling        neutral
# 1           church filled song     entailment
# 2  choir singing baseball game  contradiction
# 3                  woman young        neutral
# 4                  woman happy     entailment
#
#                                     premise_embedded  \
# 0  [0.050062012, 0.01916108, 0.009861431, 0.02031...
# 1  [0.050061963, 0.01916108, 0.009861442, 0.02031...
# 2  [0.050061963, 0.01916108, 0.009861442, 0.02031...
# 3  [-0.03839451, 0.034623183, 0.047964565, -0.011...
# 4  [-0.03839451, 0.034623183, 0.047964565, -0.011...
#
#                                  hypothesis_embedded  cosine_score
# 0  [-0.025226736, 0.042158153, 0.1098506, -0.0467...      0.342046
# 1  [-0.03397217, 0.045834888, 0.023162806, -0.018...      0.664867
# 2  [0.029779846, 0.062454868, -0.040203903, -0.09...      0.563270
# 3  [-0.015306637, 0.0011524818, -0.01608309, -0.0...      0.309873
# 4  [0.016856875, 0.0070528723, -0.025405552, 0.00...      0.511601

# %% [markdown]
# ### Save data to pickle files

# %%
def save_to_pickle(df, filename):
  df.to_pickle(filename)

# %%
save_to_pickle(processed_train_data, '/content/drive/MyDrive/ml-project-data-try/snli-sbert-dataset/train.pickle')
save_to_pickle(processed_val_data, '/content/drive/MyDrive/ml-project-data-try/snli-sbert-dataset/validation.pickle')
save_to_pickle(processed_test_data, '/content/drive/MyDrive/ml-project-data-try/snli-sbert-dataset/test.pickle')
