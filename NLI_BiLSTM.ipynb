# %% [markdown]
# ### Imports

# %%
import pandas as pd
import torch
import matplotlib.pyplot as plt
import pickle

import tempfile
from tensorflow.keras.models import Model
from keras.optimizers import Adam, RMSprop
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import Input, Embedding, Dense, Dropout, TimeDistributed
from tensorflow.keras.layers import BatchNormalization, Bidirectional, LSTM, concatenate
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.utils import to_categorical
import os
import numpy as np
from tabulate import tabulate

import warnings
warnings.filterwarnings('ignore')

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
def read_df_and_display_num_rows_columns(filepath):
    with open(filepath, "rb") as file:
      data = pickle.load(file)
    print(f"Reading file: {filepath}")
    print(f"number of rows: {data.shape[0]}")
    print(f"number of columns: {data.shape[1]}")
    return data

# %%
df_train = read_df_and_display_num_rows_columns("/content/drive/MyDrive/ml-project-data-try/snli-sbert-dataset/train.pickle")
df_val = read_df_and_display_num_rows_columns("/content/drive/MyDrive/ml-project-data-try/snli-sbert-dataset/validation.pickle")
df_test = read_df_and_display_num_rows_columns("/content/drive/MyDrive/ml-project-data-try/snli-sbert-dataset/test.pickle")
# Out:
# Reading file: /content/drive/MyDrive/ml-project-data-try/snli-sbert-dataset/train.pickle
# number of rows: 549350
# number of columns: 6
# Reading file: /content/drive/MyDrive/ml-project-data-try/snli-sbert-dataset/validation.pickle
# number of rows: 9842
# number of columns: 6
# Reading file: /content/drive/MyDrive/ml-project-data-try/snli-sbert-dataset/test.pickle
# number of rows: 9824
# number of columns: 6

# %%
df_train.head()
# Out:
#                               premise                         hypothesis  \
# 0  person horse jumps broken airplane  person training horse competition
# 1  person horse jumps broken airplane     person diner ordering omelette
# 2  person horse jumps broken airplane              person outdoors horse
# 3      children smiling waving camera                    smiling parents
# 4      children smiling waving camera                   children present
#
#            label                                   premise_embedded  \
# 0        neutral  [-0.010034064, 0.0028005873, 0.0631274, 0.0080...
# 1  contradiction  [-0.010034064, 0.0028005873, 0.0631274, 0.0080...
# 2     entailment  [-0.010034064, 0.0028005873, 0.0631274, 0.0080...
# 3        neutral  [-0.021928668, 0.06378024, 0.017834725, -0.032...
# 4     entailment  [-0.021928668, 0.06378024, 0.017834725, -0.032...
#
#                                  hypothesis_embedded  cosine_score
# 0  [-0.050083168, 0.020744428, 0.006436512, -0.00...      0.387597
# 1  [0.01991658, 0.08336658, 0.05666334, -0.005686...      0.048144
# 2  [-0.015296373, 0.051944993, 0.06472147, -0.013...      0.514768
# 3  [-0.038321618, 0.09435368, 0.0064652245, 0.039...      0.594589
# 4  [-0.018334052, 0.032883544, -0.014544778, 0.03...      0.569901

# %%
output_dimension = 384
lstm_units = 128
trainable = False #we do not want weights of the embedding layer to be updated during the training process
hidden_size = 128

# %%
# Parameters
L2 = 4e-6
DROPOUT = 0.2
LEARNING_RATE = 0.01
RHO = 0.9
EPSILON = 1e-08
DECAY = 0.0

CATEGORIES = 3
BATCH_SIZE = 512
TRAINING_EPOCHS = 25

PATIENCE = 5

# %%
def preprocess_data_for_nli(df):
    # Define MAX_SEQ_LEN and NUM_CLASSES
    processed_data = []

    label_map = {'contradiction': 0, 'neutral': 1, 'entailment': 2}
    # Replace string labels with numerical labels
    df['label'] = df['label'].replace(label_map)
    
    for index, row in df.iterrows():
        # Get label, premise, and hypothesis from the row
        label = row['label']
        premise = row['premise_embedded']
        hypothesis = row['hypothesis_embedded']
        
        label_new = to_categorical(label, num_classes=3)
        
        # Append the processed data as a tuple to the list
        processed_data.append((premise, hypothesis, label_new))
    
    return pd.DataFrame(processed_data, columns=['premise', 'hypothesis', 'label'])

# %%
df_train_copy = df_train.copy()
processed_train_data = preprocess_data_for_nli(df_train_copy)
processed_train_data.head()
# Out:
#                                              premise  \
# 0  [-0.010034064, 0.0028005873, 0.0631274, 0.0080...
# 1  [-0.010034064, 0.0028005873, 0.0631274, 0.0080...
# 2  [-0.010034064, 0.0028005873, 0.0631274, 0.0080...
# 3  [-0.021928668, 0.06378024, 0.017834725, -0.032...
# 4  [-0.021928668, 0.06378024, 0.017834725, -0.032...
#
#                                           hypothesis            label
# 0  [-0.050083168, 0.020744428, 0.006436512, -0.00...  [0.0, 1.0, 0.0]
# 1  [0.01991658, 0.08336658, 0.05666334, -0.005686...  [1.0, 0.0, 0.0]
# 2  [-0.015296373, 0.051944993, 0.06472147, -0.013...  [0.0, 0.0, 1.0]
# 3  [-0.038321618, 0.09435368, 0.0064652245, 0.039...  [0.0, 1.0, 0.0]
# 4  [-0.018334052, 0.032883544, -0.014544778, 0.03...  [0.0, 0.0, 1.0]

# %%
data_val_copy = df_val.copy()
processed_val_data = preprocess_data_for_nli(data_val_copy)
processed_val_data.head()
# Out:
#                                              premise  \
# 0  [0.0042251493, -0.003406235, -0.0019028404, 0....
# 1  [0.0042251493, -0.003406235, -0.0019028404, 0....
# 2  [0.0042251493, -0.003406235, -0.0019028404, 0....
# 3  [-0.08395465, 0.033306517, 0.05497519, -0.0349...
# 4  [-0.08395465, 0.033306517, 0.05497519, -0.0349...
#
#                                           hypothesis            label
# 0  [0.024690624, 0.09049612, 0.030129503, -0.0052...  [0.0, 1.0, 0.0]
# 1  [-0.07236776, -0.020317988, -0.034565713, 0.02...  [0.0, 0.0, 1.0]
# 2  [0.035375293, 0.042607836, -0.0109004835, 0.00...  [1.0, 0.0, 0.0]
# 3  [-0.085580505, 0.06142286, 0.04118396, -0.0191...  [0.0, 0.0, 1.0]
# 4  [-0.035818074, 0.0477772, 0.06401619, -0.03154...  [0.0, 1.0, 0.0]

# %%
def BL_model_train(train_data):
    
    BiLSTM = Bidirectional(LSTM(lstm_units))
    translation = TimeDistributed(Dense(output_dimension, activation='relu'))
    
    premise = Input(shape=(384,), dtype='float32')
    hypothesis = Input(shape=(384,), dtype='float32')

    premise_reshaped = Reshape((1, 384))(premise)
    hypothesis_reshaped = Reshape((1, 384))(hypothesis)

    premise_timeDistributed = translation(premise_reshaped)
    hypothesis_timeDistributed = translation(hypothesis_reshaped)
    
    premise_BiLSTM = BiLSTM(premise_timeDistributed)
    hypothesis_BiLSTM = BiLSTM(hypothesis_timeDistributed)
    
    premise_normalized = BatchNormalization()(premise_BiLSTM)
    hypothesis_normalized = BatchNormalization()(hypothesis_BiLSTM)
    
    train_input = concatenate([premise_normalized, hypothesis_normalized])
    train_input = Dropout(0.2)(train_input)
    
    for _ in range(3):
        train_input = Dense(2 * hidden_size, activation='relu', kernel_regularizer=l2(4e-6))(train_input)
        train_input = Dropout(0.2)(train_input)
        train_input = BatchNormalization()(train_input)
  
    prediction = Dense(3, activation='softmax')(train_input)
    
    model = Model(inputs=[premise, hypothesis], outputs=prediction)
    optimizer = Adam(learning_rate=0.01)
    
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    model.summary()
    
    return model

# %%
from tensorflow.keras.layers import Reshape

def BL_model_train(train_data):
    BiLSTM = Bidirectional(LSTM(lstm_units))
    translation = TimeDistributed(Dense(output_dimension, activation='relu'))
    
    premise = Input(shape=(384,), dtype='float32')
    hypothesis = Input(shape=(384,), dtype='float32')

    premise_reshaped = Reshape((1, 384))(premise)
    hypothesis_reshaped = Reshape((1, 384))(hypothesis)

    premise_timeDistributed = translation(premise_reshaped)
    hypothesis_timeDistributed = translation(hypothesis_reshaped)
    
    premise_BiLSTM = BiLSTM(premise_timeDistributed)
    hypothesis_BiLSTM = BiLSTM(hypothesis_timeDistributed)
    
    premise_normalized = BatchNormalization()(premise_BiLSTM)
    hypothesis_normalized = BatchNormalization()(hypothesis_BiLSTM)
    
    train_input = concatenate([premise_normalized, hypothesis_normalized])
    train_input = Dropout(0.2)(train_input)
    
    for i in range(3):
        train_input = Dense(2 * hidden_size, activation='relu', kernel_regularizer=l2(4e-6))(train_input)
        train_input = Dropout(0.2)(train_input)
        train_input = BatchNormalization()(train_input)
  
    prediction = Dense(3, activation='softmax')(train_input)
    
    model = Model(inputs=[premise, hypothesis], outputs=prediction)
    optimizer = Adam(learning_rate=0.01)
    
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    model.summary()
    
    return model

# %%
import tensorflow as tf
tensor_premise = tf.convert_to_tensor(tf.constant(processed_train_data['premise'].tolist()))
tensor_hypothesis = tf.convert_to_tensor(tf.constant(processed_train_data['hypothesis'].tolist()))
tensor_label = tf.convert_to_tensor(tf.constant(processed_train_data['label'].tolist()))

# %%
val_premise = tf.convert_to_tensor(tf.constant(processed_val_data['premise'].tolist()))
val_hypothesis = tf.convert_to_tensor(tf.constant(processed_val_data['hypothesis'].tolist()))
val_label = tf.convert_to_tensor(tf.constant(processed_val_data['label'].tolist()))

# %%
print("Training model")

model = BL_model_train(processed_train_data)
    # ReduceLROnPlateau callback to reduce learning rate when the validation accuracy plateaus
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience=PATIENCE, verbose=1, factor=0.5, min_lr=0.00001)
# early_stopping = EarlyStopping(monitor='val_loss', patience=PATIENCE)

_, tmpfn = tempfile.mkstemp()
model_checkpoint = ModelCheckpoint(tmpfn, save_best_only=True, save_weights_only=True)
# callbacks = [early_stopping, model_checkpoint, learning_rate_reduction]
callbacks = [model_checkpoint, learning_rate_reduction]
# Train model
history = model.fit(x=[tensor_premise, tensor_hypothesis], y=tensor_label, batch_size=BATCH_SIZE, epochs=TRAINING_EPOCHS, validation_data=([val_premise, val_hypothesis], val_label), callbacks=callbacks)
# Restore the best found model during validation
model.load_weights(tmpfn)
# Out:
# Training model
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_9 (InputLayer)           [(None, 384)]        0           []
#
#  input_10 (InputLayer)          [(None, 384)]        0           []
#
#  reshape_8 (Reshape)            (None, 1, 384)       0           ['input_9[0][0]']
#
#  reshape_9 (Reshape)            (None, 1, 384)       0           ['input_10[0][0]']
#
#  time_distributed_4 (TimeDistri  (None, 1, 384)      147840      ['reshape_8[0][0]',
#  buted)                                                           'reshape_9[0][0]']
#
#  bidirectional_4 (Bidirectional  (None, 256)         525312      ['time_distributed_4[0][0]',
#  )                                                                'time_distributed_4[1][0]']
#
#  batch_normalization_20 (BatchN  (None, 256)         1024        ['bidirectional_4[0][0]']
#  ormalization)
#
#  batch_normalization_21 (BatchN  (None, 256)         1024        ['bidirectional_4[1][0]']
#  ormalization)
#
#  concatenate_4 (Concatenate)    (None, 512)          0           ['batch_normalization_20[0][0]',
#                                                                   'batch_normalization_21[0][0]']
#
#  dropout_16 (Dropout)           (None, 512)          0           ['concatenate_4[0][0]']
#
#  dense_21 (Dense)               (None, 256)          131328      ['dropout_16[0][0]']
#
#  dropout_17 (Dropout)           (None, 256)          0           ['dense_21[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 256)         1024        ['dropout_17[0][0]']
#  ormalization)
#
#  dense_22 (Dense)               (None, 256)          65792       ['batch_normalization_22[0][0]']
#
#  dropout_18 (Dropout)           (None, 256)          0           ['dense_22[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 256)         1024        ['dropout_18[0][0]']
#  ormalization)
#
#  dense_23 (Dense)               (None, 256)          65792       ['batch_normalization_23[0][0]']
#
#  dropout_19 (Dropout)           (None, 256)          0           ['dense_23[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 256)         1024        ['dropout_19[0][0]']
#  ormalization)
#
#  dense_24 (Dense)               (None, 3)            771         ['batch_normalization_24[0][0]']
#
# ==================================================================================================
# Total params: 941,955
# Trainable params: 939,395
# Non-trainable params: 2,560
# __________________________________________________________________________________________________
# Epoch 1/25
# 1073/1073 [==============================] - 22s 14ms/step - loss: 0.7848 - accuracy: 0.6596 - val_loss: 0.6824 - val_accuracy: 0.7202 - lr: 0.0100
# Epoch 2/25
# 1073/1073 [==============================] - 14s 13ms/step - loss: 0.7057 - accuracy: 0.7070 - val_loss: 0.6746 - val_accuracy: 0.7260 - lr: 0.0100
# Epoch 3/25
# 1073/1073 [==============================] - 14s 13ms/step - loss: 0.6868 - accuracy: 0.7207 - val_loss: 0.6643 - val_accuracy: 0.7345 - lr: 0.0100
# Epoch 4/25
# 1073/1073 [==============================] - 14s 13ms/step - loss: 0.6742 - accuracy: 0.7309 - val_loss: 0.6431 - val_accuracy: 0.7485 - lr: 0.0100
# Epoch 5/25
# 1073/1073 [==============================] - 14s 13ms/step - loss: 0.6651 - accuracy: 0.7369 - val_loss: 0.6474 - val_accuracy: 0.7476 - lr: 0.0100
# Epoch 6/25
# 1073/1073 [==============================] - 14s 13ms/step - loss: 0.6565 - accuracy: 0.7431 - val_loss: 0.6559 - val_accuracy: 0.7497 - lr: 0.0100
# Epoch 7/25
# 1073/1073 [==============================] - 14s 13ms/step - loss: 0.6479 - accuracy: 0.7471 - val_loss: 0.6446 - val_accuracy: 0.7516 - lr: 0.0100
# Epoch 8/25
# 1073/1073 [==============================] - 14s 13ms/step - loss: 0.6394 - accuracy: 0.7516 - val_loss: 0.6470 - val_accuracy: 0.7461 - lr: 0.0100
# Epoch 9/25
# 1073/1073 [==============================] - 14s 13ms/step - loss: 0.6325 - accuracy: 0.7552 - val_loss: 0.6401 - val_accuracy: 0.7514 - lr: 0.0100
# Epoch 10/25
# 1073/1073 [==============================] - 13s 12ms/step - loss: 0.6258 - accuracy: 0.7590 - val_loss: 0.6412 - val_accuracy: 0.7516 - lr: 0.0100
# Epoch 11/25
# 1073/1073 [==============================] - 13s 12ms/step - loss: 0.6174 - accuracy: 0.7625 - val_loss: 0.6563 - val_accuracy: 0.7431 - lr: 0.0100
# Epoch 12/25
# 1072/1073 [============================>.] - ETA: 0s - loss: 0.6136 - accuracy: 0.7648
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# 1073/1073 [==============================] - 14s 13ms/step - loss: 0.6136 - accuracy: 0.7648 - val_loss: 0.6476 - val_accuracy: 0.7508 - lr: 0.0100
# Epoch 13/25
# 1073/1073 [==============================] - 13s 12ms/step - loss: 0.5702 - accuracy: 0.7833 - val_loss: 0.6176 - val_accuracy: 0.7621 - lr: 0.0050
# Epoch 14/25
# 1073/1073 [==============================] - 14s 13ms/step - loss: 0.5490 - accuracy: 0.7919 - val_loss: 0.6169 - val_accuracy: 0.7615 - lr: 0.0050
# Epoch 15/25
# 1073/1073 [==============================] - 13s 12ms/step - loss: 0.5360 - accuracy: 0.7975 - val_loss: 0.6241 - val_accuracy: 0.7654 - lr: 0.0050
# Epoch 16/25
# 1073/1073 [==============================] - 13s 12ms/step - loss: 0.5255 - accuracy: 0.8021 - val_loss: 0.6287 - val_accuracy: 0.7594 - lr: 0.0050
# Epoch 17/25
# 1073/1073 [==============================] - 13s 12ms/step - loss: 0.5165 - accuracy: 0.8065 - val_loss: 0.6310 - val_accuracy: 0.7560 - lr: 0.0050
# Epoch 18/25
# 1073/1073 [==============================] - 13s 12ms/step - loss: 0.5089 - accuracy: 0.8100 - val_loss: 0.6311 - val_accuracy: 0.7585 - lr: 0.0050
# Epoch 19/25
# 1073/1073 [==============================] - 13s 12ms/step - loss: 0.5025 - accuracy: 0.8128 - val_loss: 0.6254 - val_accuracy: 0.7589 - lr: 0.0050
# Epoch 20/25
# 1072/1073 [============================>.] - ETA: 0s - loss: 0.4956 - accuracy: 0.8159
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# 1073/1073 [==============================] - 14s 13ms/step - loss: 0.4956 - accuracy: 0.8158 - val_loss: 0.6280 - val_accuracy: 0.7600 - lr: 0.0050
# Epoch 21/25
# 1073/1073 [==============================] - 13s 12ms/step - loss: 0.4632 - accuracy: 0.8304 - val_loss: 0.6441 - val_accuracy: 0.7614 - lr: 0.0025
# Epoch 22/25
# 1073/1073 [==============================] - 13s 12ms/step - loss: 0.4470 - accuracy: 0.8377 - val_loss: 0.6366 - val_accuracy: 0.7622 - lr: 0.0025
# Epoch 23/25
# 1073/1073 [==============================] - 13s 12ms/step - loss: 0.4380 - accuracy: 0.8405 - val_loss: 0.6445 - val_accuracy: 0.7623 - lr: 0.0025
# Epoch 24/25
# 1073/1073 [==============================] - 13s 12ms/step - loss: 0.4300 - accuracy: 0.8438 - val_loss: 0.6506 - val_accuracy: 0.7591 - lr: 0.0025
# Epoch 25/25
# 1071/1073 [============================>.] - ETA: 0s - loss: 0.4244 - accuracy: 0.8465
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# 1073/1073 [==============================] - 15s 14ms/step - loss: 0.4245 - accuracy: 0.8464 - val_loss: 0.6509 - val_accuracy: 0.7600 - lr: 0.0025

# %%
def plot_model_training(hist):
  """Function to plot accuracy and loss for iterations for the training and validation data set of the model
     Args:
       model: trained model"""
  fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
  # Plot accuracy
  ax1.plot(hist.history['accuracy'])
  ax1.plot(hist.history['val_accuracy'])
  ax1.set_title('Model Accuracy')
  ax1.set_ylabel('Accuracy')
  ax1.set_xlabel('Epoch')
  ax1.legend(['Train', 'Validation'], loc='upper right')

  # Plot loss
  ax2.plot(hist.history['loss'])
  ax2.plot(hist.history['val_loss'])
  ax2.set_title('Model Loss')
  ax2.set_ylabel('Loss')
  ax2.set_xlabel('Epoch')
  ax2.legend(['Train', 'Validation'], loc='upper right')

  plt.show()

# %%
plot_model_training(history)

# %%
# Save the model as h5 file
model.save("/content/drive/MyDrive/ml-project-data-try/trained-models/BiLSTM/NLI-BiLSTM.h5")
